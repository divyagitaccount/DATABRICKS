# %% [markdown]
# ## EXPLORING FUNDAMENTALS OF DATABRICKS
# #### DESCRIPTION - *we are about to get dive into the fundamentals of databricks*
# #### $${\color{GREEN} DIVYA }$$

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.mobile_metrics;

# %%
# %fs
ls /Volumes/workspace/default/volume1/mobile_os_usage.csv
